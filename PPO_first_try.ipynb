# %%
pip install panda_gym torchvision av
# Out:
# Collecting panda_gym
#   Downloading panda_gym-3.0.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Collecting av
#   Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: gymnasium>=0.26 in /opt/conda/lib/python3.10/site-packages (from panda_gym) (0.29.0)
# Collecting pybullet (from panda_gym)
#   Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from panda_gym) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from panda_gym) (1.14.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26->panda_gym) (0.0.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)
# Downloading panda_gym-3.0.7-py3-none-any.whl (23 kB)
# Downloading av-14.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 58.8 MB/s eta 0:00:00:00:0100:01
# Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 16.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pybullet, av, panda_gym
# Successfully installed av-14.0.1 panda_gym-3.0.7 pybullet-3.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import panda_gym

from stable_baselines3 import PPO
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.callbacks import BaseCallback

import torch
import torch.nn as nn
import torchvision.models as models

import panda_ppo_utils
from panda_ppo_utils import (
                             ObservationWrapper, 
                             FeaturesExtractor,
                             ValidationCallback,
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
resnet18 = models.resnet18(pretrained=True)
feature_extractor = torch.nn.Sequential(*list(resnet18.children())[:-1]) 
feature_extractor.eval()
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 171MB/s]
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
train_env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
train_env = ObservationWrapper(train_env)

val_env = gym.make("PandaPickAndPlace-v3", render_mode="rgb_array")
val_env = ObservationWrapper(val_env)

policy_kwargs = dict(
    features_extractor_class=FeaturesExtractor,
    features_extractor_kwargs=dict(feature_extractor=feature_extractor, features_dim=258),  
    net_arch=dict(pi=[128], vf=[128])
)

model = PPO(
    policy="CnnPolicy",
    env=train_env,
    policy_kwargs=policy_kwargs,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    learning_rate=3e-4,
    gamma=0.99,
    gae_lambda=0.95,
    verbose=1,
    device=device
)

validation_callback = ValidationCallback(
    validation_env=val_env,
    validation_steps=20000, 
    output_filename="validation_video",
    fps=10,
    max_steps=200,
    verbose=1
)
# Out:
# pybullet build time: Nov 28 2023 23:45:17
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000, callback=validation_callback)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -50      |
# | time/              |          |
# |    fps             | 4        |
# |    iterations      | 1        |
# |    time_elapsed    | 491      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 49.4         |
# |    ep_rew_mean          | -49.4        |
# | time/                   |              |
# |    fps                  | 3            |
# |    iterations           | 2            |
# |    time_elapsed         | 1040         |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0061873477 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 4.11e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.44         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000414    |
# |    std                  | 0.99         |
# |    value_loss           | 15.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 3           |
# |    time_elapsed         | 1590        |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007404966 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00128     |
# |    std                  | 0.993       |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 4           |
# |    time_elapsed         | 2139        |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007820774 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00439    |
# |    std                  | 0.987       |
# |    value_loss           | 24.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | -48.1       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 5           |
# |    time_elapsed         | 2688        |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015588881 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.982       |
# |    value_loss           | 9.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.8        |
# |    ep_rew_mean          | -47.7       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 6           |
# |    time_elapsed         | 3249        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015443014 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.977       |
# |    value_loss           | 9.49        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.3       |
# |    ep_rew_mean          | -48.2      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 7          |
# |    time_elapsed         | 3809       |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01518164 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.58      |
# |    explained_variance   | 0.635      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.48       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.000452  |
# |    std                  | 0.975      |
# |    value_loss           | 6.83       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | -49.1       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 8           |
# |    time_elapsed         | 4371        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019236563 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.969       |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 9           |
# |    time_elapsed         | 4929        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015886534 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.631       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.964       |
# |    value_loss           | 3.13        |
# -----------------------------------------
# Валидация на 20000 шагах, сохраняем в validation_video_20000.mp4
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 10         |
# |    time_elapsed         | 5587       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.01674689 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.48      |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.304      |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00819   |
# |    std                  | 0.945      |
# |    value_loss           | 1.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 11          |
# |    time_elapsed         | 6148        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021504685 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.455       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00432    |
# |    std                  | 0.934       |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 12          |
# |    time_elapsed         | 6710        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026870547 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.39       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.357       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00846    |
# |    std                  | 0.931       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 13          |
# |    time_elapsed         | 7273        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.023033917 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.38       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00424    |
# |    std                  | 0.928       |
# |    value_loss           | 3.9         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -49        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 14         |
# |    time_elapsed         | 7837       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02828556 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.35      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.15       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.011     |
# |    std                  | 0.92       |
# |    value_loss           | 0.865      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 15          |
# |    time_elapsed         | 8397        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.027891144 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000405   |
# |    std                  | 0.909       |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 16          |
# |    time_elapsed         | 8953        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.034283973 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.29       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.911       |
# |    value_loss           | 0.667       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 17          |
# |    time_elapsed         | 9516        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.026466615 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00181     |
# |    std                  | 0.903       |
# |    value_loss           | 2.28        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.1       |
# |    ep_rew_mean          | -47        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 18         |
# |    time_elapsed         | 10078      |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03514105 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.24      |
# |    explained_variance   | 0.635      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.319      |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00372   |
# |    std                  | 0.896      |
# |    value_loss           | 8.13       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -49        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 19         |
# |    time_elapsed         | 10676      |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03826195 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.2       |
# |    explained_variance   | 0.896      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.142      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00527    |
# |    std                  | 0.885      |
# |    value_loss           | 0.94       |
# ----------------------------------------
# Валидация на 40000 шагах, сохраняем в validation_video_40000.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 20          |
# |    time_elapsed         | 11346       |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.023399703 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.14       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0723      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000307    |
# |    std                  | 0.873       |
# |    value_loss           | 0.363       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 21          |
# |    time_elapsed         | 11915       |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021548767 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.09       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0577      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00936    |
# |    std                  | 0.864       |
# |    value_loss           | 2.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 22          |
# |    time_elapsed         | 12491       |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018742286 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0839      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00719    |
# |    std                  | 0.861       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 23          |
# |    time_elapsed         | 13064       |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.024464007 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0095     |
# |    std                  | 0.854       |
# |    value_loss           | 3.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 24          |
# |    time_elapsed         | 13646       |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020361058 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.115       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00195    |
# |    std                  | 0.854       |
# |    value_loss           | 3.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | -47         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 25          |
# |    time_elapsed         | 14223       |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019904518 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00946    |
# |    std                  | 0.852       |
# |    value_loss           | 6.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 26          |
# |    time_elapsed         | 14803       |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.019544158 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00598    |
# |    std                  | 0.838       |
# |    value_loss           | 2.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 27          |
# |    time_elapsed         | 15382       |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.021525726 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.92       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0508      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.836       |
# |    value_loss           | 0.624       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 28          |
# |    time_elapsed         | 15964       |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.021469831 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.89       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0382      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00622    |
# |    std                  | 0.826       |
# |    value_loss           | 4.59        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.1       |
# |    ep_rew_mean          | -46        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 29         |
# |    time_elapsed         | 16547      |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02017707 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.85      |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.9       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00679   |
# |    std                  | 0.823      |
# |    value_loss           | 4.53       |
# ----------------------------------------
# Валидация на 60000 шагах, сохраняем в validation_video_60000.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.6        |
# |    ep_rew_mean          | -45.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 30          |
# |    time_elapsed         | 17226       |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.021396196 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.83       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.8        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.817       |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 31          |
# |    time_elapsed         | 17809       |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.023828778 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0722      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00347    |
# |    std                  | 0.816       |
# |    value_loss           | 4.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 32          |
# |    time_elapsed         | 18391       |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.037863694 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | -0.202      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0564      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00564     |
# |    std                  | 0.815       |
# |    value_loss           | 0.519       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 33          |
# |    time_elapsed         | 18962       |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.022347275 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0589      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00717    |
# |    std                  | 0.814       |
# |    value_loss           | 2.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 34          |
# |    time_elapsed         | 19526       |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.020209257 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0267      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00839    |
# |    std                  | 0.803       |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48          |
# |    ep_rew_mean          | -48         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 35          |
# |    time_elapsed         | 20079       |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.027296366 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0311      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00793    |
# |    std                  | 0.796       |
# |    value_loss           | 4.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -47.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 36          |
# |    time_elapsed         | 20636       |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023841508 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00409    |
# |    std                  | 0.794       |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -47.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 37          |
# |    time_elapsed         | 21189       |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.035026375 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00444     |
# |    std                  | 0.792       |
# |    value_loss           | 6.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 38          |
# |    time_elapsed         | 21754       |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.029838366 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0151      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00677    |
# |    std                  | 0.788       |
# |    value_loss           | 0.605       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 39         |
# |    time_elapsed         | 22320      |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03179994 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.65      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0896     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00744   |
# |    std                  | 0.791      |
# |    value_loss           | 0.156      |
# ----------------------------------------
# Валидация на 80000 шагах, сохраняем в validation_video_80000.mp4
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 47.5      |
# |    ep_rew_mean          | -47.5     |
# | time/                   |           |
# |    fps                  | 3         |
# |    iterations           | 40        |
# |    time_elapsed         | 22978     |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0329556 |
# |    clip_fraction        | 0.319     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.64     |
# |    explained_variance   | 0.801     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0336    |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.00291  |
# |    std                  | 0.787     |
# |    value_loss           | 3.51      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48         |
# |    ep_rew_mean          | -48        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 41         |
# |    time_elapsed         | 23543      |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03172836 |
# |    clip_fraction        | 0.288      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 0.738      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0106     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00794   |
# |    std                  | 0.786      |
# |    value_loss           | 2.72       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 42          |
# |    time_elapsed         | 24108       |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.035556406 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00163     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.785       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | -47         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 43          |
# |    time_elapsed         | 24675       |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.044094406 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0289      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00973    |
# |    std                  | 0.787       |
# |    value_loss           | 4.35        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 47.5      |
# |    ep_rew_mean          | -47.5     |
# | time/                   |           |
# |    fps                  | 3         |
# |    iterations           | 44        |
# |    time_elapsed         | 25236     |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0381109 |
# |    clip_fraction        | 0.325     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.62     |
# |    explained_variance   | 0.72      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0293    |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.00266  |
# |    std                  | 0.788     |
# |    value_loss           | 5.28      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | -47.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 45          |
# |    time_elapsed         | 25799       |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.039187275 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.63       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00954    |
# |    std                  | 0.791       |
# |    value_loss           | 3.04        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 47.5       |
# |    ep_rew_mean          | -47.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 46         |
# |    time_elapsed         | 26362      |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03896451 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0453     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.000691  |
# |    std                  | 0.788      |
# |    value_loss           | 4.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.5        |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 47          |
# |    time_elapsed         | 26923       |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.039838888 |
# |    clip_fraction        | 0.356       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.59       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0438      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.782       |
# |    value_loss           | 5.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 48          |
# |    time_elapsed         | 27486       |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.033192053 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.56       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0775      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00737    |
# |    std                  | 0.779       |
# |    value_loss           | 0.15        |
# -----------------------------------------
# Валидация на 100000 шагах, сохраняем в validation_video_100000.mp4
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 49          |
# |    time_elapsed         | 28141       |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.043968648 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0832      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00324    |
# |    std                  | 0.779       |
# |    value_loss           | 3.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49.5       |
# |    ep_rew_mean          | -49.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 50         |
# |    time_elapsed         | 28703      |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.04575904 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.53      |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0749     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00799   |
# |    std                  | 0.777      |
# |    value_loss           | 0.268      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49          |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 51          |
# |    time_elapsed         | 29287       |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.036253303 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0058      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00857    |
# |    std                  | 0.779       |
# |    value_loss           | 0.509       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | -47         |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 52          |
# |    time_elapsed         | 29848       |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.057440724 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0166      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.773       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.6        |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 53          |
# |    time_elapsed         | 30427       |
# |    total_timesteps      | 108544      |
# ...
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 64         |
# |    time_elapsed         | 36755      |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.08560505 |
# |    clip_fraction        | 0.421      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.29      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0331    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0213    |
# |    std                  | 0.736      |
# |    value_loss           | 0.0895     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.5        |
# |    ep_rew_mean          | -49.5       |
# | time/                   |             |
# |    fps                  | 3           |
# |    iterations           | 65          |
# |    time_elapsed         | 37310       |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.087981485 |
# |    clip_fraction        | 0.419       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.735       |
# |    value_loss           | 0.214       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -49        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 66         |
# |    time_elapsed         | 37865      |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.14404082 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.26      |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0408    |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.0166    |
# |    std                  | 0.73       |
# |    value_loss           | 1.28       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 67         |
# |    time_elapsed         | 38422      |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.13307476 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.22      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00924   |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.0108    |
# |    std                  | 0.724      |
# |    value_loss           | 2.04       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 68         |
# |    time_elapsed         | 38974      |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.18624774 |
# |    clip_fraction        | 0.493      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.18      |
# |    explained_variance   | 0.75       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0123    |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.00294   |
# |    std                  | 0.717      |
# |    value_loss           | 1.75       |
# ----------------------------------------
# Валидация на 140000 шагах, сохраняем в validation_video_140000.mp4
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 49         |
# |    ep_rew_mean          | -49        |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 69         |
# |    time_elapsed         | 39645      |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.13734794 |
# |    clip_fraction        | 0.455      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0192    |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0169    |
# |    std                  | 0.716      |
# |    value_loss           | 0.627      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 70         |
# |    time_elapsed         | 40203      |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.23208928 |
# |    clip_fraction        | 0.497      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.16      |
# |    explained_variance   | 0.658      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.038      |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.00778   |
# |    std                  | 0.718      |
# |    value_loss           | 1.52       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 71         |
# |    time_elapsed         | 40761      |
# |    total_timesteps      | 145408     |
# | train/                  |            |
# |    approx_kl            | 0.18645814 |
# |    clip_fraction        | 0.482      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.15      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0098     |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0154    |
# |    std                  | 0.711      |
# |    value_loss           | 0.833      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 48.5       |
# |    ep_rew_mean          | -48.5      |
# | time/                   |            |
# |    fps                  | 3          |
# |    iterations           | 72         |
# |    time_elapsed         | 41311      |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.17319494 |
# |    clip_fraction        | 0.477      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.13      |
# |    explained_variance   | 0.784      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0364    |
# |    n_updates            | 710        |
# |    policy_gradient_loss | -0.0197    |
# |    std                  | 0.71       |
# |    value_loss           | 1.52       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 49        |
# |    ep_rew_mean          | -49       |
# | time/                   |           |
# |    fps                  | 3         |
# |    iterations           | 73        |
# |    time_elapsed         | 41861     |
# |    total_timesteps      | 149504    |
# | train/                  |           |
# |    approx_kl            | 0.1662318 |
# |    clip_fraction        | 0.482     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.14     |
# |    explained_variance   | 0.808     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.034    |
# |    n_updates            | 720       |
# |    policy_gradient_loss | -0.0128   |
# |    std                  | 0.716     |
# |    value_loss           | 0.228     |
# ---------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 49
#      39 validation_callback = ValidationCallback(
#      40     validation_env=validation_env,
#      41     validation_steps=20000,  # Проверять каждые 5000 шагов
#    (...)
#      45     verbose=1
#      46 )
#      48 # Обучение с валидацией на GPU
# ---> 49 model.learn(total_timesteps=1000000, callback=validation_callback)
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/ppo/ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:259, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
# --> 259     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     261     if continue_training is False:
#     262         break
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File /opt/conda/lib/python3.10/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File /opt/conda/lib/python3.10/site-packages/gymnasium/core.py:509, in ObservationWrapper.step(self, action)
#     507 """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
#     508 observation, reward, terminated, truncated, info = self.env.step(action)
# --> 509 return self.observation(observation), reward, terminated, truncated, info
#
# Cell In[6], line 20, in ObservationWrapper.observation(self, observation)
#      18 def observation(self, observation):
#      19     # Получаем изображение через render()
# ---> 20     image = self.env.render()
#      21     image = Image.fromarray(image)  # Преобразуем в PIL.Image
#      22     image = transform(image).numpy().flatten()  # Преобразуем в плоский массив
#
# File /opt/conda/lib/python3.10/site-packages/gymnasium/core.py:457, in Wrapper.render(self)
#     455 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     456     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 457     return self.env.render()
#
# File /opt/conda/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:70, in OrderEnforcing.render(self, *args, **kwargs)
#      65 if not self._disable_render_order_enforcing and not self._has_reset:
#      66     raise ResetNeeded(
#      67         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      68         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69     )
# ---> 70 return self.env.render(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:67, in PassiveEnvChecker.render(self, *args, **kwargs)
#      65     return env_render_passive_checker(self.env, *args, **kwargs)
#      66 else:
# ---> 67     return self.env.render(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/panda_gym/envs/core.py:338, in RobotTaskEnv.render(self)
#     330 def render(self) -> Optional[np.ndarray]:
#     331     """Render.
#     332
#     333     If render mode is "rgb_array", return an RGB array of the scene. Else, do nothing and return None.
#    (...)
#     336         RGB np.ndarray or None: An RGB array if mode is 'rgb_array', else None.
#     337     """
# --> 338     return self.sim.render(
#     339         width=self.render_width,
#     340         height=self.render_height,
#     341         target_position=self.render_target_position,
#     342         distance=self.render_distance,
#     343         yaw=self.render_yaw,
#     344         pitch=self.render_pitch,
#     345         roll=self.render_roll,
#     346     )
#
# File /opt/conda/lib/python3.10/site-packages/panda_gym/pybullet.py:143, in PyBullet.render(self, width, height, target_position, distance, yaw, pitch, roll)
#     132 view_matrix = self.physics_client.computeViewMatrixFromYawPitchRoll(
#     133     cameraTargetPosition=target_position,
#     134     distance=distance,
#    (...)
#     138     upAxisIndex=2,
#     139 )
#     140 proj_matrix = self.physics_client.computeProjectionMatrixFOV(
#     141     fov=60, aspect=float(width) / height, nearVal=0.1, farVal=100.0
#     142 )
# --> 143 (_, _, rgba, _, _) = self.physics_client.getCameraImage(
#     144     width=width,
#     145     height=height,
#     146     viewMatrix=view_matrix,
#     147     projectionMatrix=proj_matrix,
#     148     shadow=True,
#     149     renderer=p.ER_BULLET_HARDWARE_OPENGL,
#     150 )
#     151 # With Python3.10, pybullet return flat tuple instead of array. So we need to build create the array.
#     152 rgba = np.array(rgba, dtype=np.uint8).reshape((height, width, 4))
#
# KeyboardInterrupt:
